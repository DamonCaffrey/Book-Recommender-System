# %%
import pandas as pd
import numpy as np

import requests as rq
from bs4 import BeautifulSoup as bs

# %%
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_coffee_production'

page = rq.get(url).text
soup = bs(page)

# %%
table = soup.find('table')
top_10_countries = []

# %%
rank = []
country = []
sixty_kilogram_bags = []
metric_tons = []
pounds = []

# %%
for row in table.find_all('tr')[1:]:
    temp = row.text.replace('\n\n', '\t').replace(',','').strip()
    temp_list = temp.split('\t')
    
#     print(temp)
#     print(temp_list)

    rank.append(temp_list[0])
    country.append(temp_list[1])
    sixty_kilogram_bags.append(int(temp_list[2]))
    metric_tons.append(int(temp_list[3]))
    pounds.append(int(temp_list[4]))

# %%
dict_df = {"Country" : country, 
           "60 Kilogram Bags" : sixty_kilogram_bags, 
           "Metric Tons" : metric_tons, 
           "Pounds" : pounds}

# %%
df = pd.DataFrame(dict_df, index=rank)
# df.reset_index(drop=True, inplace=True)
# df.set_index(pd.Index(df.Rank))
df
# Out:
#                               Country  60 Kilogram Bags  Metric Tons  \
# 1                              Brazil          44200000      2652000
# 2                             Vietnam          27500000      1650000
# 3                            Colombia          13500000       810000
# 4                           Indonesia          11000000       660000
# 5                            Ethiopia           6400000       384000
# 6                            Honduras           5800000       348000
# 7                               India           5800000       348000
# 8                              Uganda           4800000       288000
# 9                              Mexico           3900000       234000
# 10                          Guatemala           3400000       204000
# 11                               Peru           3200000       192000
# 12                          Nicaragua           2200000       132000
# 13             China(2013–14 est.)[7]           1947000       116820
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,4))

sns.barplot(dict_df['Country'][:10], dict_df['Metric Tons'][:10])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,4))

sns.lineplot(dict_df['Country'][:10], dict_df['Metric Tons'][:10])
sns.lineplot(dict_df['Country'][:10], dict_df['60 Kilogram Bags'][:10])
# sns.lineplot(dict_df['Country'][:10], dict_df['Pounds'][:10])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>
